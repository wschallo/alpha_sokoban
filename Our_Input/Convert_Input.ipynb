# %%
#s="###\n#@#\n#$#\n#.#\n###"
#s="########\n#. #   #\n#  $   #\n#   # ##\n## # $.#\n#   $  #\n#  .# @#\n########"
#s="########\n#  .# .#\n# $   @#\n# $$## #\n#     .#\n########"
#s="####  \n# .#  \n#  ###\n#*@  #\n#  $ #\n#  ###\n####  "#input00
#s="  ###### \n  #    # \n  # ##@##\n### # $ #\n# ..# $ #\n#       #\n#  ######\n####     "#input01
#s='####   \n#  ####\n# . . #\n# $$#@#\n##    #\n ######'#input02
#s='  #### \n ##  # \n##@$.##\n# $$  #\n# . . #\n###   #\n  #####'#input03
#s='####### \n#     # \n#@$$$ ##\n#  #...#\n##    ##\n ###### '#input04
#s='####    \n#  ###  \n#    ###\n#  $*@ #\n### .# #\n  #    #\n  ######'#input05
#s='######## \n#      # \n# #### # \n# #...@# \n# ###$###\n# #     #\n#  $$ $ #\n####   ##\n   #.### \n   ###   '#input06
#s='###########  \n#     #   ###\n# $@$ # .  .#\n# ## ### ## #\n# #       # #\n# #   #   # #\n# ######### #\n#           #\n#############'#input07
#s=' #####\n #   #\n # . #\n## * #\n#  *##\n#  @##\n## $ #\n #   #\n #####'#input08
#s='###########\n#    .##  #\n# $$@..$$ #\n#   ##.   #\n###########'#input09
#s='  #####      \n  #   #      \n  # # #######\n  #  *  #   #\n  ## ##   # #\n  #     #*  #\n### # # # ###\n#  *#$+   #  \n# #   ## ##  \n#   #  *  #  \n####### # #  \n      #   #  \n      #####  '#input10
#s='######   \n#    ####\n#    ...#\n#    ...#\n######  #\n  #  #  #\n  # $$ ##\n  # @$  #\n  # $$  #\n  ## $# #\n   #    #\n   ######'#input11
#s=' ######    \n # .  #    \n##$.# #    \n#  *  #    \n# ..###    \n##$ # #####\n## ## #   #\n#  #### # #\n#   @ $ $ #\n##  #     #\n ##########'#input12
#s='   ####     \n   #  #     \n ###  #     \n##  $ #     \n#   # #     \n# #$$ ######\n# #   #   .#\n#  $  @   .#\n###  ####..#\n  ####  ####'#input13
#s=' ############################\n #                          #\n # ######################## #\n # #                      # #\n # # #################### # #\n # # #                  # # #\n # # # ################ # # #\n # # # #              # # # #\n # # # # ############ # # # #\n # # # # #            # # # #\n # # # # # ############ # # #\n # # # # #              # # #\n # # # # ################ # #\n # # # #                  # #\n##$# # #################### #\n#. @ #                      #\n#############################'#input14
s='    ######               #### \n#####*#  #################  ##\n#   ###                      #\n#        ########  ####  ##  #\n### ####     #  ####  ####  ##\n#*# # .# # # #     #     #   #\n#*# #  #     # ##  # ##  ##  #\n###    ### ###  # ##  # ##  ##\n #   # #*#      #     # #    #\n #   # ###  #####  #### #    #\n #####   #####  ####### ######\n #   # # #**#               # \n## # #   #**#  #######  ##  # \n#    #########  #    ##### ###\n# #             # $        #*#\n#   #########  ### @#####  #*#\n#####       #### ####   ######'#input15

# %%
print(s)
# Out:
#     ######               ####
# #####*#  #################  ##
# #   ###                      #
# #        ########  ####  ##  #
# ### ####     #  ####  ####  ##
# #*# # .# # # #     #     #   #
# #*# #  #     # ##  # ##  ##  #
# ###    ### ###  # ##  # ##  ##
#  #   # #*#      #     # #    #
#  #   # ###  #####  #### #    #
#  #####   #####  ####### ######
#  #   # # #**#               #
# ## # #   #**#  #######  ##  #
# #    #########  #    ##### ###
# # #             # $        #*#
# #   #########  ### @#####  #*#
# #####       #### ####   ######

# %%
file = open("input15.txt", "w") 
file.write(s) 
file.close()

# %%
p='@'
w='#'
s1='.'
s2='+'
s3='*'
b='$'
c=(len(s)-s.count('\n'))//(s.count('\n')+1)
r=s.count('\n')+1
x2=[]
x3=[]
x4=[]
x5=[]
for pos, char in enumerate(s):
    if char == w:
        x2.extend([pos//(c+1)+1,pos%(c+1)+1])        
    if char == b or char==s3:
        x3.extend([pos//(c+1)+1,pos%(c+1)+1])        
    if char == s1 or char==s2 or char==s3:
        x4.extend([pos//(c+1)+1,pos%(c+1)+1])        
    if char == p or char==s2:
        x5.extend([pos//(c+1)+1,pos%(c+1)+1])        
print(c,r)
print(len(x2)//2,*x2)
print(len(x3)//2,*x3)
print(len(x4)//2,*x4)
print(*x5)
# Out:
# 30 17
# ...

# %%
with open('sokoban15.txt', 'w') as f:
    print(c,r, file=f)
    print(len(x2)//2,*x2, file=f)
    print(len(x3)//2,*x3, file=f)
    print(len(x4)//2,*x4, file=f)
    print(*x5, file=f)
